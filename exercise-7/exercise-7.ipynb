# %%
# read in the file and make dictionaies for DBH at each census

in_file = open ("/home/eeb177-student/Desktop/eeb-177/class-assignments/21-February-Classwork/cocoli.txt")
sizes_94 = {}
sizes_97 = {}
sizes_98 = {}

# get rid of the header row
in_file.readline()

# work on all subsequent lines, one at a time
for line in in_file:
    items = line.split()
    #retrieve relevant columns
    tree_id = items[0]
    s94 = float(items[4])
    s97 = float(items[5])
    s98 = float(items[6])
    
    # populate our dictionaries 
    sizes_94[tree_id] = s94
    sizes_97[tree_id] = s97
    sizes_98[tree_id] = s98
    
    
in_file.close()

# %%
type(sizes_94["008211"])
# Out:
# float

# %%
import matplotlib.pyplot as plt 

# let's make a historgram of DBHs in 1994
# matplotlib works on lsits, so let's make one

sizes_in_1994 = list(sizes_94.values())

# %%
plt.hist(sizes_in_1994, log = False)
plt.show()

# There are some negative values in the dbh columns so this value over 8000 is actually a lie

# %%
sizes_in_1994 = list(sizes_94.values())
sizes_in_1998 = list(sizes_98.values())

f, (ax1, ax2) = plt.subplots(1, 2,sharex = True, sharey = True)
ax1.hist(sizes_in_1994, log = True)
ax1.set_title('Hist in 1994')
ax2.hist(sizes_in_1998, log = True)
ax2.set_title('Hist in 1998')
plt.show()

# %%
# exclude all values equal to -2 and add to the existing list 
sizes_in_1994[:] = (value for value in sizes_in_1994 if value != -2)

# %%
sizes_in_1994
# Out:
# [258.0,
#  19.0,
#  28.0,
#  261.0,
#  12.0,
#  105.0,
#  32.0,
#  12.0,
#  10.0,
#  18.0,
#  26.0,
#  83.0,
#  166.0,
#  92.0,
#  42.0,
#  17.0,
#  26.0,
#  193.0,
#  58.0,
#  27.0,
#  12.0,
#  12.0,
#  14.0,
#  13.0,
#  14.0,
#  301.0,
#  23.0,
#  10.0,
#  10.0,
#  42.0,
#  12.0,
#  193.0,
#  24.0,
#  81.0,
#  30.0,
#  88.0,
#  355.0,
#  33.0,
#  14.0,
#  14.0,
#  19.0,
#  11.0,
#  55.0,
#  11.0,
#  17.0,
#  22.0,
#  10.0,
#  67.0,
#  60.0,
#  11.0,
#  14.0,
#  20.0,
#  11.0,
#  13.0,
#  17.0,
#  74.0,
#  144.0,
#  885.0,
#  76.0,
#  29.0,
#  24.0,
#  13.0,
#  20.0,
#  110.0,
#  163.0,
#  18.0,
#  69.0,
#  33.0,
#  49.0,
#  17.0,
#  91.0,
#  14.0,
#  40.0,
#  11.0,
#  60.0,
#  479.0,
#  79.0,
#  33.0,
#  165.0,
#  12.0,
#  29.0,
#  11.0,
#  55.0,
#  43.0,
#  37.0,
#  21.0,
#  32.0,
#  221.0,
#  17.0,
#  27.0,
#  64.0,
#  25.0,
#  72.0,
#  14.0,
#  105.0,
#  28.0,
#  98.0,
#  132.0,
#  18.0,
#  19.0,
#  63.0,
#  510.0,
#  39.0,
#  25.0,
#  28.0,
#  15.0,
#  31.0,
#  337.0,
#  18.0,
#  24.0,
#  156.0,
#  13.0,
#  16.0,
#  118.0,
#  30.0,
#  14.0,
#  149.0,
#  19.0,
#  39.0,
#  239.0,
#  23.0,
#  23.0,
#  59.0,
#  36.0,
#  22.0,
#  14.0,
#  24.0,
#  14.0,
#  40.0,
#  477.0,
#  11.0,
#  42.0,
#  19.0,
#  10.0,
#  24.0,
#  15.0,
#  18.0,
#  239.0,
#  21.0,
#  19.0,
#  16.0,
#  21.0,
#  31.0,
#  52.0,
#  14.0,
#  39.0,
#  759.0,
#  27.0,
#  45.0,
#  175.0,
#  424.0,
#  10.0,
#  22.0,
#  18.0,
#  16.0,
#  19.0,
#  12.0,
#  11.0,
#  43.0,
#  25.0,
#  19.0,
#  14.0,
#  14.0,
#  30.0,
#  24.0,
#  62.0,
#  92.0,
#  13.0,
#  267.0,
#  15.0,
#  114.0,
#  109.0,
#  160.0,
#  14.0,
#  43.0,
#  84.0,
#  463.0,
#  12.0,
#  25.0,
#  23.0,
#  12.0,
#  16.0,
#  90.0,
#  12.0,
#  12.0,
#  17.0,
#  23.0,
#  15.0,
#  11.0,
#  18.0,
#  15.0,
#  50.0,
#  59.0,
#  13.0,
#  42.0,
#  81.0,
#  34.0,
#  15.0,
#  15.0,
#  267.0,
#  71.0,
#  20.0,
#  29.0,
#  17.0,
#  16.0,
#  57.0,
#  37.0,
#  48.0,
#  83.0,
#  23.0,
#  21.0,
#  15.0,
#  31.0,
#  73.0,
#  18.0,
#  18.0,
#  26.0,
#  13.0,
#  82.0,
#  31.0,
#  22.0,
#  13.0,
#  39.0,
#  26.0,
#  25.0,
#  11.0,
#  12.0,
#  12.0,
#  173.0,
#  19.0,
#  279.0,
#  13.0,
#  21.0,
#  126.0,
#  24.0,
#  290.0,
#  10.0,
#  17.0,
#  20.0,
#  29.0,
#  14.0,
#  17.0,
#  55.0,
#  27.0,
#  778.0,
#  35.0,
#  17.0,
#  17.0,
#  297.0,
#  120.0,
#  13.0,
#  20.0,
#  219.0,
#  52.0,
#  455.0,
#  30.0,
#  174.0,
#  24.0,
#  43.0,
#  28.0,
#  33.0,
#  15.0,
#  13.0,
#  20.0,
#  23.0,
#  15.0,
#  14.0,
#  13.0,
#  31.0,
#  18.0,
#  57.0,
#  47.0,
#  12.0,
#  32.0,
#  92.0,
#  12.0,
#  23.0,
#  62.0,
#  21.0,
#  39.0,
#  23.0,
#  70.0,
#  26.0,
#  28.0,
#  26.0,
#  52.0,
#  13.0,
#  19.0,
#  172.0,
#  24.0,
#  15.0,
#  257.0,
#  32.0,
#  10.0,
#  16.0,
#  118.0,
#  33.0,
#  277.0,
#  14.0,
#  11.0,
#  18.0,
#  12.0,
#  11.0,
#  12.0,
#  31.0,
#  13.0,
#  107.0,
#  353.0,
#  17.0,
#  28.0,
#  17.0,
#  12.0,
#  19.0,
#  143.0,
#  135.0,
#  18.0,
#  23.0,
#  20.0,
#  61.0,
#  14.0,
#  53.0,
#  18.0,
#  53.0,
#  655.0,
#  30.0,
#  28.0,
#  26.0,
#  48.0,
#  38.0,
#  60.0,
#  20.0,
#  108.0,
#  34.0,
#  28.0,
#  19.0,
#  42.0,
#  25.0,
#  421.0,
#  18.0,
#  16.0,
#  14.0,
#  13.0,
#  41.0,
#  40.0,
#  10.0,
#  21.0,
#  17.0,
#  17.0,
#  30.0,
#  20.0,
#  25.0,
#  32.0,
#  117.0,
#  22.0,
#  12.0,
#  23.0,
#  36.0,
#  12.0,
#  39.0,
#  40.0,
#  13.0,
#  19.0,
#  37.0,
#  13.0,
#  28.0,
#  35.0,
#  24.0,
#  14.0,
#  30.0,
#  232.0,
#  24.0,
#  13.0,
#  32.0,
#  19.0,
#  21.0,
#  11.0,
#  36.0,
#  23.0,
#  21.0,
#  23.0,
#  205.0,
#  21.0,
#  13.0,
#  22.0,
#  12.0,
#  13.0,
#  71.0,
#  13.0,
#  228.0,
#  539.0,
#  20.0,
#  35.0,
#  29.0,
#  259.0,
#  42.0,
#  14.0,
#  12.0,
#  16.0,
#  20.0,
#  201.0,
#  41.0,
#  82.0,
#  24.0,
#  66.0,
#  74.0,
#  30.0,
#  48.0,
#  68.0,
#  23.0,
#  352.0,
#  65.0,
#  120.0,
#  22.0,
#  134.0,
#  10.0,
#  144.0,
#  874.0,
#  198.0,
#  18.0,
#  43.0,
#  27.0,
#  13.0,
#  115.0,
#  18.0,
#  48.0,
#  36.0,
#  25.0,
#  50.0,
#  41.0,
#  91.0,
#  394.0,
#  15.0,
#  11.0,
#  18.0,
#  17.0,
#  19.0,
#  49.0,
#  39.0,
#  273.0,
#  27.0,
#  16.0,
#  10.0,
#  32.0,
#  338.0,
#  150.0,
#  23.0,
#  19.0,
#  24.0,
#  247.0,
#  180.0,
#  18.0,
#  66.0,
#  11.0,
#  58.0,
#  147.0,
#  13.0,
#  95.0,
#  255.0,
#  17.0,
#  28.0,
#  17.0,
#  16.0,
#  12.0,
#  19.0,
#  10.0,
#  14.0,
#  82.0,
#  103.0,
#  166.0,
#  19.0,
#  10.0,
#  17.0,
#  19.0,
#  41.0,
#  13.0,
#  13.0,
#  12.0,
#  45.0,
#  50.0,
#  51.0,
#  30.0,
#  42.0,
#  29.0,
#  17.0,
#  21.0,
#  16.0,
#  135.0,
#  34.0,
#  45.0,
#  18.0,
#  13.0,
#  106.0,
#  14.0,
#  10.0,
#  97.0,
#  11.0,
#  14.0,
#  12.0,
#  59.0,
#  17.0,
#  37.0,
#  18.0,
#  140.0,
#  29.0,
#  21.0,
#  64.0,
#  18.0,
#  13.0,
#  19.0,
#  17.0,
#  16.0,
#  43.0,
#  32.0,
#  11.0,
#  29.0,
#  132.0,
#  11.0,
#  30.0,
#  13.0,
#  173.0,
#  19.0,
#  21.0,
#  24.0,
#  15.0,
#  42.0,
#  16.0,
#  265.0,
#  36.0,
#  238.0,
#  16.0,
#  36.0,
#  13.0,
#  75.0,
#  41.0,
#  13.0,
#  88.0,
#  12.0,
#  37.0,
#  12.0,
#  40.0,
#  14.0,
#  24.0,
#  65.0,
#  140.0,
#  487.0,
#  27.0,
#  11.0,
#  15.0,
#  27.0,
#  25.0,
#  14.0,
#  22.0,
#  59.0,
#  10.0,
#  13.0,
#  10.0,
#  27.0,
#  237.0,
#  23.0,
#  17.0,
#  62.0,
#  14.0,
#  106.0,
#  15.0,
#  56.0,
#  15.0,
#  67.0,
#  11.0,
#  58.0,
#  16.0,
#  72.0,
#  108.0,
#  65.0,
#  12.0,
#  15.0,
#  32.0,
#  20.0,
#  11.0,
#  15.0,
#  13.0,
#  53.0,
#  53.0,
#  279.0,
#  51.0,
#  13.0,
#  30.0,
#  25.0,
#  38.0,
#  22.0,
#  12.0,
#  23.0,
#  135.0,
#  12.0,
#  29.0,
#  27.0,
#  16.0,
#  57.0,
#  61.0,
#  11.0,
#  15.0,
#  18.0,
#  25.0,
#  37.0,
#  75.0,
#  25.0,
#  14.0,
#  86.0,
#  12.0,
#  22.0,
#  344.0,
#  15.0,
#  33.0,
#  12.0,
#  17.0,
#  80.0,
#  22.0,
#  57.0,
#  17.0,
#  977.0,
#  28.0,
#  91.0,
#  15.0,
#  31.0,
#  16.0,
#  10.0,
#  15.0,
#  17.0,
#  15.0,
#  28.0,
#  415.0,
#  17.0,
#  13.0,
#  26.0,
#  360.0,
#  21.0,
#  13.0,
#  52.0,
#  615.0,
#  25.0,
#  360.0,
#  34.0,
#  83.0,
#  60.0,
#  43.0,
#  16.0,
#  29.0,
#  34.0,
#  16.0,
#  16.0,
#  10.0,
#  11.0,
#  11.0,
#  14.0,
#  40.0,
#  10.0,
#  17.0,
#  41.0,
#  45.0,
#  942.0,
#  35.0,
#  61.0,
#  10.0,
#  11.0,
#  54.0,
#  28.0,
#  21.0,
#  93.0,
#  17.0,
#  87.0,
#  31.0,
#  54.0,
#  33.0,
#  16.0,
#  21.0,
#  15.0,
#  57.0,
#  24.0,
#  592.0,
#  12.0,
#  18.0,
#  431.0,
#  17.0,
#  33.0,
#  150.0,
#  13.0,
#  16.0,
#  45.0,
#  11.0,
#  778.0,
#  28.0,
#  30.0,
#  15.0,
#  52.0,
#  38.0,
#  14.0,
#  19.0,
#  17.0,
#  48.0,
#  16.0,
#  11.0,
#  12.0,
#  119.0,
#  11.0,
#  26.0,
#  12.0,
#  33.0,
#  45.0,
#  73.0,
#  10.0,
#  14.0,
#  30.0,
#  20.0,
#  13.0,
#  34.0,
#  81.0,
#  212.0,
#  21.0,
#  25.0,
#  11.0,
#  20.0,
#  37.0,
#  34.0,
#  18.0,
#  36.0,
#  25.0,
#  20.0,
#  13.0,
#  21.0,
#  14.0,
#  35.0,
#  14.0,
#  54.0,
#  12.0,
#  10.0,
#  305.0,
#  13.0,
#  32.0,
#  57.0,
#  32.0,
#  216.0,
#  65.0,
#  192.0,
#  15.0,
#  18.0,
#  23.0,
#  10.0,
#  45.0,
#  13.0,
#  57.0,
#  22.0,
#  58.0,
#  28.0,
#  25.0,
#  17.0,
#  22.0,
#  27.0,
#  12.0,
#  22.0,
#  713.0,
#  39.0,
#  17.0,
#  14.0,
#  89.0,
#  42.0,
#  27.0,
#  12.0,
#  19.0,
#  12.0,
#  64.0,
#  16.0,
#  69.0,
#  12.0,
#  10.0,
#  90.0,
#  12.0,
#  18.0,
#  11.0,
#  11.0,
#  22.0,
#  14.0,
#  24.0,
#  448.0,
#  27.0,
#  22.0,
#  32.0,
#  42.0,
#  15.0,
#  156.0,
#  17.0,
#  132.0,
#  18.0,
#  10.0,
#  45.0,
#  15.0,
#  33.0,
#  11.0,
#  19.0,
#  11.0,
#  125.0,
#  39.0,
#  10.0,
#  22.0,
#  63.0,
#  16.0,
#  71.0,
#  31.0,
#  379.0,
#  104.0,
#  34.0,
#  38.0,
#  10.0,
#  13.0,
#  15.0,
#  70.0,
#  14.0,
#  90.0,
#  14.0,
#  15.0,
#  15.0,
#  20.0,
#  27.0,
#  20.0,
#  12.0,
#  10.0,
#  36.0,
#  18.0,
#  61.0,
#  13.0,
#  14.0,
#  38.0,
#  143.0,
#  16.0,
#  135.0,
#  130.0,
#  12.0,
#  128.0,
#  28.0,
#  10.0,
#  262.0,
#  24.0,
#  12.0,
#  16.0,
#  923.0,
#  16.0,
#  22.0,
#  33.0,
#  32.0,
#  74.0,
#  40.0,
#  15.0,
#  14.0,
#  13.0,
#  94.0,
#  11.0,
#  81.0,
#  12.0,
#  17.0,
#  13.0,
#  127.0,
#  16.0,
#  24.0,
#  17.0,
#  16.0,
#  93.0,
#  35.0,
#  10.0,
#  46.0,
#  119.0,
#  42.0,
#  12.0,
#  15.0,
#  12.0,
#  40.0,
#  37.0,
#  21.0,
#  14.0,
#  42.0,
#  19.0,
#  16.0,
#  20.0,
#  20.0,
#  21.0,
#  132.0,
#  26.0,
#  23.0,
#  14.0,
#  17.0,
#  18.0,
#  24.0,
#  19.0,
#  18.0,
#  16.0,
#  42.0,
#  16.0,
#  38.0,
#  32.0,
#  17.0,
#  28.0,
#  10.0,
#  19.0,
#  98.0,
#  18.0,
#  19.0,
#  16.0,
#  24.0,
#  132.0,
#  26.0,
#  184.0,
#  19.0,
#  30.0,
#  10.0,
#  19.0,
#  23.0,
#  51.0,
#  31.0,
#  15.0,
#  37.0,
#  22.0,
#  23.0,
#  227.0,
#  32.0,
#  29.0,
#  18.0,
#  21.0,
#  53.0,
#  26.0,
#  16.0,
#  84.0,
#  44.0,
#  69.0,
#  121.0,
#  19.0,
#  22.0,
#  31.0,
#  11.0,
#  14.0,
#  33.0,
#  27.0,
#  34.0,
#  34.0,
#  629.0,
#  99.0,
#  14.0,
#  63.0,
#  13.0,
#  25.0,
#  42.0,
#  20.0,
#  27.0,
#  70.0,
#  12.0,
#  13.0,
#  18.0,
#  13.0,
#  181.0,
#  705.0,
#  14.0,
#  13.0,
#  16.0,
#  21.0,
#  19.0,
#  111.0,
#  10.0,
#  207.0,
#  77.0,
#  20.0,
#  15.0,
#  220.0,
#  312.0,
#  25.0,
#  58.0,
#  20.0,
#  17.0,
#  250.0,
#  11.0,
#  61.0,
#  66.0,
#  15.0,
#  15.0,
#  25.0,
#  19.0,
#  49.0,
#  25.0,
#  15.0,
#  13.0,
#  10.0,
#  407.0,
#  11.0,
#  27.0,
#  15.0,
#  33.0,
#  20.0,
#  28.0,
#  21.0,
#  1500.0,
#  11.0,
#  14.0,
#  10.0,
#  54.0,
#  11.0,
#  ...]

# %%
plt.hist(sizes_in_1994, log = False)
plt.show()

# %%
sizes_in_1994 = list(sizes_94.values())
sizes_in_1998 = list(sizes_98.values())
plt.plot(sizes_in_1994, sizes_in_1998, 'ro')
plt.xlabel("size in 94")
plt.ylabel("size in 98")
plt.show()

# 'ro' makes the plot red and dotted instead of the default blue and lines
